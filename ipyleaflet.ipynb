# %%
from ipyleaflet import Map, basemaps, basemap_to_tiles

# %%
import leafmap

# %%
m = leafmap.Map()
m

# %%
import geosdem.randest as r
from geosdem.randest import compute_dsdf

# %%
r.compute_dsdf(2,3)

# %%
import pandas as pd
import numpy as np
data = pd.read_csv('/home/oussoucolette/@/DONNEES/Data-obj1/foragess/Leonard/Baniindices.csv', sep=',')

data1 = pd.DataFrame(data)
data1
# Out:
#     Date   cotonyield    sojayield  maize_yield    ACDI_B   lstndvi    pcplst
# 0   2001          NaN   702.702703      1178.11 -0.432917 -0.132917  0.142500  \
# 1   2002  1446.172068   907.407407      1194.34  0.413333  0.596250 -0.070833
# 2   2003  1467.010934  1049.751244      1468.04  0.448333  0.479583  0.368750
# 3   2004  1399.996174   800.000000      1454.90  0.645833  0.607083 -0.180000
# 4   2005  1243.966775   801.223242      1501.37  0.462083  0.282083  0.043750
# 5   2006  1456.506196   949.554896      1375.72 -0.132083 -0.040833 -0.248750
# 6   2007  1458.659750   949.554896       916.70  0.035833 -0.187083 -0.190417
# 7   2008  1145.192308   990.797546      1435.46  0.305000  0.319583 -0.154167
# 8   2009  1089.276140   949.536560      1385.66 -0.170417 -0.266250 -0.372917
# 9   2010  1008.239235   850.859107      1502.95  0.156250  0.330000  0.534583
# 10  2011  1004.565861   917.486752      1629.56 -1.090000 -0.765833 -0.486667
# ...

# %%
import geosdem as g

# %%
import geosdem.randest as rn
import geosdem.metrics as mt

# %%
metrics = {}

# %%
a = mt.rmse(actual=[1,3,4,5,6,7], forecast=[5,3,6,7,2,4])
b = mt.gmrae(actual=[1,3,4,5,6,7], forecast=[5,3,6,7,2,4])
c = mt.mdrae(actual=[1,3,4,5,6,7], forecast=[5,3,6,7,2,4])
d = mt.mase(actual=[1,3,4,5,6,7], forecast=[5,3,6,7,2,4], seasonality=3)
print(a, b, c, d)
# Out:
# 2.857738033247041 0.0 0.4642857142857143 1.5

# %%
import hydroeval as he

# %%
rn.corr(data1)
# Out:
#                   Date  cotonyield  sojayield  maize_yield    ACDI_B
# Date          1.000000   -0.267743   0.727053    -0.026049 -0.429820  \
# cotonyield   -0.267743    1.000000   0.185761    -0.152526  0.238429
# sojayield     0.727053    0.185761   1.000000     0.096518 -0.240751
# maize_yield  -0.026049   -0.152526   0.096518     1.000000  0.158733
# ACDI_B       -0.429820    0.238429  -0.240751     0.158733  1.000000
# lstndvi      -0.616965    0.051094  -0.334042     0.185432  0.844676
# pcplst       -0.029182   -0.158004   0.112281     0.285966  0.504341
# pcpndvi      -0.534232    0.301259  -0.221119     0.155798  0.870256
# pcpsm         0.157769    0.318881   0.063628    -0.072970  0.548194
# smlst         0.001817    0.110058  -0.084026    -0.022725  0.663915
# smndvi       -0.360017    0.383252  -0.279990    -0.057731  0.857583
# pcplstndvi   -0.570332    0.090904  -0.288005     0.229986  0.869538
# pcpsmlst      0.124133    0.112436   0.086615     0.114301  0.701260
# ...
